# %% [markdown]
# # Extract Job Posts from Indeed

# %% [markdown]
# Before extracting job posts from [Indeed](https://www.indeed.com/), make sure you have checked their [robots.txt](https://www.indeed.com/robots.txt) file.

# %% [markdown]
# ## Create a table in database

# %%
import pandas
import configparser
import psycopg2
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# Read the database connection info from the config.ini

# %%
config = configparser.ConfigParser()
config.read('config.ini')

host = config['myaws']['host']
db = config['myaws']['db']
user = config['myaws']['user']
pwd = config['myaws']['pwd']

# %% [markdown]
# Establish a connection to the databas, and create a cursor.

# %%
conn = psycopg2.connect(host = host,
                       user = user,
                        password = pwd,
                        dbname = db
                       )
cur = conn.cursor()

# %% [markdown]
# Design the table in SQL

# %%
# replace the schema and table name to your schema and table name
table_sql = """
            CREATE TABLE IF NOT EXISTS gp2.indeed
            (
                id SERIAL,
                job_title VARCHAR(200),
                job_company VARCHAR(200),
                job_loc VARCHAR(200),
                job_salary VARCHAR(200),
                job_summary TEXT,
                PRIMARY KEY(id)
            );

            """

# %% [markdown]
# create the table

# %%
cur.execute(table_sql)
conn.commit()

# %% [markdown]
# ## Request HTML
#
# [urllib.request](https://docs.python.org/3/library/urllib.request.html) makes simple HTTP requests to visit a web page and get the content via the Python standard library.
# Here we define the URL to search job pots about Intelligence analyst.

# %%
url = 'https://www.indeed.com/jobs?q=intelligence+analyst&start=0'

# %%
import urllib.request
response = urllib.request.urlopen(url)
html_data= response.read()
#print(html_data.decode('utf-8'))

# %% [markdown]
# # Parese HTML
# We can use the inspector tool in browsers to analyze webpages and use [beautifulsoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) to extract webpage data.
# pip install the beautiful soup if needed.

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from beautifulsoup4) (1.9.5)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_data,'html.parser')
#print (soup)

# %% [markdown]
# Use the <code> tag.find_all(‘tag_name’, tage_attr = ‘possible_value’)</code> function to return a list of tags where the attribute equals the possible_value.
# <ul>Common attributes include:
# <li> id</li>
# <li> class<span style ="color:red">_</span></li>
# </ul>
#
# <ul>Common functions include:
# <li> tag.text: return the visible part of the tag</li>
# <li> tag.get(‘attribute’): return the value of the attribute of the tag</li>
# </ul>

# %% [markdown]
# Since all the job posts are in the <code>div tag class = 'jobsearch-Sprep...'</code>, we need to find that div tag from the body tag.

# %%
for table_resultsBody in soup.find_all('table', id = 'resultsBody'):
    pass
    #print(table_resultsBody)

# %%
for table_pageContent in table_resultsBody.find_all('table', id = 'pageContent'):
    pass
    #print(table_pageContent)

# %%
for td_resultsCol in table_pageContent.find_all('td', id = 'resultsCol'):
    pass
    #print(td_resultsCol)

# %% [markdown]
# ## Save Data to Database
# Now we find the div tag contains the job posts. We need to identify the job title, company, ratings, reviews, salary, and summary.
# We can save those records to our table in the database.

# %%
#  identify the job title, company, ratings, reviews, salary, and summary
for div_row in td_resultsCol.find_all('div', class_='jobsearch-SerpJobCard unifiedRow row result'):

    # find job title
    job_title = None
    job_company  = None
    job_rating = None
    job_loc = None
    job_salary = None
    job_summary = None
    for h2_title in div_row.find_all('h2', class_ = 'title'):
       
        job_title = h2_title.a.text.strip().replace("'","_")
   
    for div_dsc in div_row.find_all('div', class_ = 'sjcl'):
        
        #find company name
        for span_company in div_dsc.find_all('span', class_ = 'company'):
            job_company = span_company.text.strip().replace("'","_")
        
        # find location
        for div_loc in div_dsc.find_all('div', class_ = 'location accessible-contrast-color-location'):
            job_loc = div_loc.text.strip().replace("'","_")
    
    # find salary
    for div_salary in div_row.find_all('div',class_ ='salarySnippet'):
        job_salary = div_salary.text.strip().replace("'","_")
    
    #find summary
    for div_summary in div_row.find_all('div', class_ = 'summary'):
        job_summary = div_summary.text.strip().replace("'","_")
        
    # insert into database
    
    sql_insert = """
                insert into gp2.indeed(job_title,job_company,job_loc,job_salary,job_summary)
                values('{}','{}','{}','{}','{}')            
                """.format(job_title,job_company,job_loc,job_salary,job_summary)

    cur.execute(sql_insert)
    conn.commit()

# %% [markdown]
# ## View the Table

# %%
df = pandas.read_sql_query('select * from gp2.indeed', conn)
df[:]
# Out:
#     id                                          job_title  \
# 0    1                      Criminal Intelligence Analyst
# 1    2                               Intelligence Analyst
# 2    3                              Investigative Analyst
# 3    4                 Looker Data Analyst (Fully Remote)
# 4    5                                  Help Desk Analyst
# 5    6                               Intelligence Analyst
# 6    7               Threat Intelligence Response Analyst
# 7    8                                      Crime Analyst
# 8    9                 INTELLIGENCE OPERATIONS SPECIALIST
# 9   10        Linguist/Language Analyst (Russian/Chinese)
# 10  11              Criminal Intelligence Analyst, Senior
# 11  12                               Intelligence Analyst
# 12  13                                   Economic Analyst
# 13  14                               Intelligence Analyst
# 14  15                               Intelligence Analyst
# 15  16                      Criminal Intelligence Analyst
# 16  17                               Intelligence Analyst
# 17  18                              Investigative Analyst
# 18  19                 Looker Data Analyst (Fully Remote)
# 19  20                                  Help Desk Analyst
# 20  21                               Intelligence Analyst
# 21  22               Threat Intelligence Response Analyst
# 22  23                                      Crime Analyst
# 23  24                 INTELLIGENCE OPERATIONS SPECIALIST
# 24  25        Linguist/Language Analyst (Russian/Chinese)
# 25  26              Criminal Intelligence Analyst, Senior
# 26  27                               Intelligence Analyst
# 27  28                                   Economic Analyst
# 28  29                               Intelligence Analyst
# 29  30                               Intelligence Analyst
# 30  31                               Intelligence Analyst
# 31  32                        Threat Intelligence Analyst
# 32  33                               Intelligence Analyst
# 33  34                        Junior Intelligence Analyst
# 34  35               Crisis Response Intelligence Analyst
# 35  36  Threat Intelligence Analyst, Intel Synthesis, ...
# 36  37             Criminal Intelligence Analyst I (FFTL)
# 37  38                       Senior Data analyst (REMOTE)
# 38  39                      Intelligence Analyst (Remote)
# 39  40                        Intelligence Analyst Intern
# 40  41                               INTELLIGENCE ANALYST
# 41  42    Graduate Studies Program - Intelligence Analyst
# 42  43                 Intelligence Operations Specialist
# 43  44                       Virtual Intelligence Analyst
# 44  45  Undergraduate Internship/Co-op Program - Intel...
#
#                                 job_company job_loc  \
# 0      Hillsborough County Sheriff_s Office    None
# 1                          Northrop Grumman    None
# 2                     At-Risk International    None
# 3                               Data Driven    None
# 4                                       IBM    None
# 5                   Halfaker and Associates    None
# 6                           Recorded Future    None
# 7                    City of North Port, FL    None
# 8                  US Department of Defense    None
# 9                  National Security Agency    None
# 10                       City of Dallas, TX    None
# 11                                      GTL    None
# 12              Central Intelligence Agency    None
# 13                                Pinkerton    None
# 14       Array Information Technology, Inc.    None
# 15     Hillsborough County Sheriff_s Office    None
# 16                         Northrop Grumman    None
# 17                    At-Risk International    None
# 18                              Data Driven    None
# 19                                      IBM    None
# 20                  Halfaker and Associates    None
# 21                          Recorded Future    None
# 22                   City of North Port, FL    None
# 23                 US Department of Defense    None
# 24                 National Security Agency    None
# 25                       City of Dallas, TX    None
# 26                                      GTL    None
# 27              Central Intelligence Agency    None
# 28                                Pinkerton    None
# 29       Array Information Technology, Inc.    None
# 30                    5 Stones intelligence    None
# 31                       Ford Motor Company    None
# 32  General Dynamics Information Technology    None
# 33              Valiant Integrated Services    None
# 34                                Pinkerton    None
# 35                                   Google    None
# 36                 Commonwealth of Kentucky    None
# 37                         Elevate Textiles    None
# 38                              CrowdStrike    None
# 39                               Everbridge    None
# 40                              Intellistar    None
# 41              Central Intelligence Agency    None
# 42   Transportation Security Administration    None
# 43                                      G4S    None
# 44              Central Intelligence Agency    None
#
#                     job_salary  \
# 0         Up to $77,542 a year
# 1                         None
# 2     $55,000 - $75,000 a year
# 3     $55,000 - $70,000 a year
# 4                         None
# 5                         None
# 6                         None
# 7      $18.20 - $27.29 an hour
# 8   $101,585 - $132,064 a year
# 9     $64,009 - $99,741 a year
# 10    $41,490 - $60,086 a year
# 11                        None
# 12   $57,495 - $157,709 a year
# 13                        None
# 14                        None
# 15        Up to $77,542 a year
# 16                        None
# 17    $55,000 - $75,000 a year
# 18    $55,000 - $70,000 a year
# 19                        None
# 20                        None
# 21                        None
# 22     $18.20 - $27.29 an hour
# 23  $101,585 - $132,064 a year
# 24    $64,009 - $99,741 a year
# 25    $41,490 - $60,086 a year
# 26                        None
# 27   $57,495 - $157,709 a year
# 28                        None
# 29                        None
# 30                        None
# 31                        None
# 32                        None
# 33                        None
# 34                        None
# 35                        None
# 36                        None
# 37           $29 - $38 an hour
# 38                        None
# 39                        None
# 40                        None
# 41     $26.28 - $37.51 an hour
# 42    $52,700 - $99,586 a year
# 43                        None
# 44     $21.21 - $22.43 an hour
#
#                                           job_summary
# 0   Experience with a law enforcement or military ...
# 1   Successful candidates in this position will co...
# 2   Investigative Analyst will provide technical a...
# 3   You have prior experience with a business inte...
# 4   Strong technical skills (2 years).\nKnowledge ...
# 5   Must also demonstrate the ability to conduct r...
# 6   Partner with clients and effectively relay str...
# 7   Responsible technical civilian position perfor...
# 8   Substitution of education may not be used in l...
# 9   Prior military without a degree but with langu...
# 10  Bachelor_s degree in a criminal justice, foren...
# 11  Assist facility with investigations by utilizi...
# 12  Bachelor_s or Master_s degree in one of the fo...
# 13  JOB SUMMARY: The Intelligence Analyst, assigne...
# 14  .Demonstrated ability to create and provide in...
# 15  Experience with a law enforcement or military ...
# 16  Successful candidates in this position will co...
# 17  Investigative Analyst will provide technical a...
# 18  You have prior experience with a business inte...
# 19  Strong technical skills (2 years).\nKnowledge ...
# 20  Must also demonstrate the ability to conduct r...
# 21  Partner with clients and effectively relay str...
# 22  Responsible technical civilian position perfor...
# 23  Substitution of education may not be used in l...
# 24  Prior military without a degree but with langu...
# 25  Bachelor_s degree in a criminal justice, foren...
# 26  Assist facility with investigations by utilizi...
# 27  Bachelor_s or Master_s degree in one of the fo...
# 28  JOB SUMMARY: The Intelligence Analyst, assigne...
# 29  .Demonstrated ability to create and provide in...
# 30  Analyze threat information from multiple sourc...
# 31  This will involve the use of a variety of tool...
# 32  Bringing the expertise needed to understand an...
# 33  Use analytic tools to create charts, maps, tim...
# 34  Master_s degree in political science, internat...
# 35  Ability to work effectively cross-functionally...
# 36  This may require specialized training or focus...
# 37  Knowledge of statistical tools and business re...
# 38  Undergraduate degree, military training or rel...
# 39  Conduct research into existing risk intelligen...
# 40  Associates degree or an additional four years ...
# 41  Engineering, science students, or those in oth...
# 42  Advanced technical knowledge of intelligence c...
# 43  Experience learning and quickly becoming profi...
# 44  Engineering, science students, or those in oth...

# %% [markdown]
# ## Query the Table

# %%
df = pandas.read_sql_query('select count(*) as count,job_title from gp2.indeed group by job_title order by count desc ', conn)
df[:]
# Out:
#     count                                          job_title
# 0      12                               Intelligence Analyst
# 1       2                                  Help Desk Analyst
# 2       2               Threat Intelligence Response Analyst
# 3       2                                   Economic Analyst
# 4       2              Criminal Intelligence Analyst, Senior
# 5       2                 Looker Data Analyst (Fully Remote)
# 6       2                 INTELLIGENCE OPERATIONS SPECIALIST
# 7       2        Linguist/Language Analyst (Russian/Chinese)
# 8       2                              Investigative Analyst
# 9       2                                      Crime Analyst
# 10      2                      Criminal Intelligence Analyst
# 11      1                        Junior Intelligence Analyst
# 12      1                       Virtual Intelligence Analyst
# 13      1               Crisis Response Intelligence Analyst
# 14      1                        Threat Intelligence Analyst
# 15      1                       Senior Data analyst (REMOTE)
# 16      1             Criminal Intelligence Analyst I (FFTL)
# 17      1  Threat Intelligence Analyst, Intel Synthesis, ...
# 18      1  Undergraduate Internship/Co-op Program - Intel...
# 19      1                               INTELLIGENCE ANALYST
# 20      1                        Intelligence Analyst Intern
# 21      1                      Intelligence Analyst (Remote)
# 22      1    Graduate Studies Program - Intelligence Analyst
# 23      1                 Intelligence Operations Specialist

# %%
df = pandas.read_sql_query('select count(*) as count,job_title from gp2.indeed group by job_title order by count desc ', conn)
df.plot.bar(x='job_title')

# %%
cur.close()
conn.close()
